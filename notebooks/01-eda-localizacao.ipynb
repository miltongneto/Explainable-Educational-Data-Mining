# %% [markdown]
# # Exploratory Data Analysis - Coordenadas
# Endereços das escolas e adição de informações externas de acordo com a localização

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from unidecode import unidecode
import geopandas as gpd
from shapely.geometry import Point

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Carregar dados

# %%
PATH = '../data/raw'

# %% [markdown]
# ### Dados das coordenadas

# %%
# Edição manual no arquivo "escolas_enderecos_0.csv" na linha 25881, remoção do "campo" com 00E+91
data = pd.read_csv(os.path.join(PATH, 'escolas_enderecos_0.csv'), sep=',')
print(data.shape)
data.head()
# Out:
# (28730, 19)
#          nomedep  depadm        mun  codmun       de  CD_ESCOLA  CD_DIRETORIA  \
# 0  ESTADUAL - SE       1  SAO PAULO     100  NORTE 1      36444         10101
# 1  ESTADUAL - SE       1  SAO PAULO     100  LESTE 5       1582         10205
# 2  ESTADUAL - SE       1  SAO PAULO     100  LESTE 5       2173         10205
# 3  ESTADUAL - SE       1  SAO PAULO     100  LESTE 1       3086         10207
# 4  ESTADUAL - SE       1  SAO PAULO     100  LESTE 1       2884         10207
#
#    CD_DIRETORIA_ESTADUAL  CD_DIRETORIA_SUPVS_PROPR  \
# 0                  10101                     10101
# 1                  10205                     10205
# 2                  10205                     10205
# 3                  10207                     10207
# 4                  10207                     10207
#
#                  NM_COMPLETO_ESCOLA  CD_UNIDADE           DS_ENDERECO  \
# 0   GENESIO DE ALMEIDA MOURA DOUTOR       37806     DOMINGOS AREVALO
# 1       DOMINGOS FAUSTINO SARMIENTO       24902          21 DE ABRIL
# 2             JOAO BORGES PROFESSOR       24901              ITAPURA
# 3  HELENA LOMBARDI BRAGA PROFESSORA       24918  VIRGINIA DE MIRANDA
# 4               RAUL PILLA DEPUTADO       24923      RUA SAO BERTOLDO
#
#   COMPLEMENTO NUMERO  CD_ORIGEM_UNIDADE  CD_ORIGEM_ESCOLA  CD_ORIGEM_ENDERECO  \
# 0         RUA    862              37806             36444               37866
# 1         RUA    970              24902              1582               24962
# 2         RUA    976              24901              2173               24961
# 3         RUA    138              24918              3086               24978
# 4         RUA    449              24923              2884               24983
#
#     LATITUDE  LONGITUDE
# 0 -23.447000 -46.696700
# 1 -23.542232 -46.605793
# 2 -23.547300 -46.566000
# 3 -23.526587 -46.452888
# 4 -23.494297 -46.457064

# %% [markdown]
# ### Dados do SARESP das escolas (2018)

# %%
df_escolas = pd.read_csv('../data/processed/desempenho_escolas_saresp_2018.csv')
print(df_escolas.shape)
df_escolas.head()
# Out:
# (5059, 4)
#    CODESC  BOM  RUIM  DESEMPENHO_ESC
# 0      12  0.0   2.0               0
# 1      24  1.0   7.0               0
# 2      36  0.0   4.0               0
# 3      48  0.0   2.0               0
# 4      59  0.0   2.0               0

# %% [markdown]
# ### Dados Externos - Informacao sobre os municipios
# A base é um compilado de diversas informações públicas dos municípios brasileiros.
#
# Dados disponíveis em: https://www.kaggle.com/crisparada/brazilian-cities

# %%
df_cidades = pd.read_csv('../data/external/BRAZIL_CITIES.csv', sep=';')
print(df_cidades.shape)
df_cidades.head()
# Out:
# (5576, 81)
#              CITY STATE  CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  \
# 0       São Paulo    SP        1    11253503.0         11133776.0
# 1          Osasco    SP        0      666740.0           664447.0
# 2  Rio De Janeiro    RJ        1     6320446.0          6264915.0
# 3        Brasília    DF        1     2570160.0          2564370.0
# 4    Porto Alegre    RS        1     1409351.0          1403450.0
#
#    IBGE_RES_POP_ESTR    IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL    IBGE_POP  \
# 0           119727.0  3576148.0      3548433.0        27715.0  10463636.0
# 1             2293.0   202009.0       202009.0            NaN    616068.0
# 2            55531.0  2147235.0      2147235.0            NaN   5426838.0
# 3             5790.0   774820.0       751558.0        23261.0   2450634.0
# 4             5901.0   508503.0       508503.0            NaN   1339712.0
#
#      IBGE_1  IBGE_1-4  IBGE_5-9  IBGE_10-14  IBGE_15-59   IBGE_60+  \
# 0  129464.0  514794.0  684443.0    783702.0   7058221.0  1293012.0
# 1    8089.0   32305.0   42733.0     49379.0    420590.0    62972.0
# 2   58958.0  235380.0  321084.0    382267.0   3559037.0   870112.0
# 3   35833.0  143641.0  190078.0    207283.0   1683918.0   189881.0
# 4   15235.0   58369.0   79310.0     93989.0    889503.0   203306.0
#
#    IBGE_PLANTED_AREA  IBGE_CROP_PRODUCTION_$  IDHM Ranking 2010   IDHM  \
# 0               94.0                  1134.0               28.0  0,805
# 1                0.0                     0.0              174.0   0,78
# 2             2098.0                 41072.0               46.0  0,799
# 3           162894.0                822413.0                9.0   0,82
# 4              766.0                  7967.0               32.0  0,805
#
#   IDHM_Renda IDHM_Longevidade IDHM_Educacao          LONG           LAT  \
# 0      0,843            0,855         0,725  -46,57038318   -23,5673865
# 1      0,776             0,84         0,718  -46,78881014    -23,533612
# 2       0,84            0,845         0,719  -43,22787512  -22,87665212
# 3      0,863            0,873         0,742  -47,88790548  -15,79408736
# 4      0,867            0,857         0,702  -51,22866046  -30,03003677
#
#        ALT     PAY_TV  FIXED_PHONES        AREA  \
# 0   783,62  2047668.0     5543127.0     1521,11
# 1   742,97    98664.0      231302.0    64954,00
# 2    11,80  1271672.0     2417123.0  1200255,00
# 3  1115,25   460682.0      920410.0  5760783,00
# 4    42,24   352371.0      663846.0      495,39
#
#                                      REGIAO_TUR CATEGORIA_TUR  ESTIMATED_POP  \
# 0                                       Capital             A     12176866.0
# 1                            Negócios E Cultura             B       696850.0
# 2                                 Metropolitana             A      6688927.0
# 3  Brasília - Patrimônio Cultural Da Humanidade             A      2974703.0
# 4                                 Porto Alegre              A      1479101.0
#
#   RURAL_URBAN GVA_AGROPEC GVA_INDUSTRY  GVA_SERVICES   GVA_PUBLIC  \
# 0      Urbano    43867,07  63306754,97  464656988,11  41902892,72
# 1      Urbano      947,16      3036,39   53111430,66   2627577,24
# 2      Urbano       81,37  36334430,50  177361095,84     47548,35
# 3      Urbano   820754,66   9659849,10  103819469,69     92051,45
# 4      Urbano    28354,58   6768083,47   48930408,04   6712383,63
#
#      GVA_TOTAL          TAXES           GDP     POP_GDP GDP_CAPITA  \
# 0  569910502,87  117125386,74  687035889,61  12038175.0   57071,43
# 1   58776349,73   15626341,33   74402691,05    696382.0  106841,78
# 2  261325243,88      68106,12  329431359,90   6498837.0   50690,82
# 3  206351521,16   29145585,42  235497106,59   2977216.0   79099,77
# 4   62439229,72   10986034,54      73425,26   1481019.0   49577,53
#
#                                             GVA_MAIN  MUN_EXPENDIT  COMP_TOT  \
# 0                                    Demais serviços  4.577250e+10  530446.0
# 1                                    Demais serviços  1.758451e+09   15315.0
# 2                                    Demais serviços  2.364284e+10  190038.0
# 3  Administração, defesa, educação e saúde públic...           NaN   86200.0
# 4                                    Demais serviços  5.358322e+09   80082.0
#
#    COMP_A  COMP_B   COMP_C  COMP_D  COMP_E   COMP_F    COMP_G   COMP_H  \
# 0   739.0    79.0  31566.0   332.0   657.0  25222.0  150633.0  19515.0
# 1    11.0     2.0    863.0     1.0    29.0    703.0    6002.0   1026.0
# 2   172.0   274.0   6824.0   235.0   272.0   7797.0   47545.0   4825.0
# 3   242.0    42.0   3269.0    22.0   130.0   4685.0   29018.0   2157.0
# 4   196.0    31.0   3482.0    57.0    95.0   4039.0   21550.0   2523.0
#
#     COMP_I   COMP_J   COMP_K   COMP_L   COMP_M   COMP_N  COMP_O   COMP_P  \
# 0  29290.0  38720.0  23738.0  14003.0  49181.0  76757.0   153.0  16030.0
# 1   1230.0    706.0    271.0    238.0    761.0   1535.0     6.0    527.0
# 2  12289.0   9070.0   6327.0   4281.0  19248.0  34812.0   120.0   6744.0
# 3   6788.0   3254.0   1527.0   1670.0   6717.0  10346.0   204.0   3043.0
# 4   4205.0   3555.0   2461.0   1924.0   8139.0  16271.0    72.0   2217.0
#
#     COMP_Q  COMP_R   COMP_S  COMP_T  COMP_U  HOTELS     BEDS  Pr_Agencies  \
# 0  22248.0  6687.0  24832.0     0.0    64.0    57.0  10022.0       1693.0
# 1    492.0   142.0    770.0     0.0     0.0     2.0    272.0         67.0
# 2   9905.0  5039.0  14224.0     0.0    35.0    94.0  13247.0        815.0
# 3   5363.0  1197.0   6403.0     0.0   123.0    23.0   4960.0        150.0
# 4   3489.0  1339.0   4429.0     0.0     8.0    17.0   3548.0        180.0
#
#    Pu_Agencies  Pr_Bank  Pu_Bank     Pr_Assets     Pu_Assets       Cars  \
# 0        626.0     83.0      8.0  1.947077e+13  2.893261e+12  5740995.0
# 1         26.0     10.0      2.0  6.732330e+12  1.321699e+10   283641.0
# 2        304.0     34.0      5.0  2.283445e+12  9.738864e+11  2039930.0
# 3        274.0     14.0      4.0  2.920933e+11  8.016164e+12  1288107.0
# 4        168.0     20.0      3.0  2.709619e+11  4.026997e+11   608777.0
#
#    Motorcycles  Wheeled_tractor  UBER    MAC  WAL-MART  POST_OFFICES
# 0    1134570.0           3236.0   1.0  130.0       7.0         225.0
# 1      73477.0            174.0   NaN    7.0       1.0          10.0
# 2     363486.0            289.0   1.0   68.0       1.0         120.0
# 3     211392.0            594.0   1.0   28.0       1.0          60.0
# 4     106829.0           1383.0   1.0   19.0      12.0          53.0

# %% [markdown]
# #### Filtrar apenas as cidades do estado de  SP

# %%
df_cidades = df_cidades[df_cidades['STATE'] == 'SP']

# %% [markdown]
# #### Ajustar os tipos dos atributos
# Alterar os tipo dos dados que foi configurado para *object* (string), quando representam um valor numérico

# %%
df_cidades.select_dtypes('object').head(2)
# Out:
#         CITY STATE   IDHM IDHM_Renda IDHM_Longevidade IDHM_Educacao  \
# 0  São Paulo    SP  0,805      0,843            0,855         0,725
# 1     Osasco    SP   0,78      0,776             0,84         0,718
#
#            LONG          LAT     ALT      AREA          REGIAO_TUR  \
# 0  -46,57038318  -23,5673865  783,62   1521,11             Capital
# 1  -46,78881014   -23,533612  742,97  64954,00  Negócios E Cultura
#
#   CATEGORIA_TUR RURAL_URBAN GVA_AGROPEC GVA_INDUSTRY  GVA_SERVICES  \
# 0             A      Urbano    43867,07  63306754,97  464656988,11
# 1             B      Urbano      947,16      3036,39   53111430,66
#
#     GVA_PUBLIC    GVA_TOTAL          TAXES           GDP GDP_CAPITA  \
# 0  41902892,72  569910502,87  117125386,74  687035889,61   57071,43
# 1   2627577,24   58776349,73   15626341,33   74402691,05  106841,78
#
#           GVA_MAIN
# 0  Demais serviços
# 1  Demais serviços

# %%
columns_to_transform = df_cidades.select_dtypes('object').columns.drop(['CITY', 'STATE', 'REGIAO_TUR', 'CATEGORIA_TUR', 'RURAL_URBAN', 'GVA_MAIN'])
df_cidades[columns_to_transform] = df_cidades[columns_to_transform].apply(lambda x: x.str.replace(',', '.').astype(float))

# %% [markdown]
# ## Estatísticas básicas

# %%
data.select_dtypes('object').describe()
# Out:
#           nomedep        mun            de  \
# count       28730      28730         28730
# unique          5        645            91
# top     MUNICIPAL  SAO PAULO  CENTRO OESTE
# freq        13184       6926           991
#
#                                        NM_COMPLETO_ESCOLA  \
# count                                               28730
# unique                                              26677
# top     INSTITUTO BRASILEIRO DE EDUCACAO PROFISSIONAL ...
# freq                                                   15
#
#                 DS_ENDERECO COMPLEMENTO NUMERO
# count                 28720       27026  28730
# unique                21362         826   3137
# top     RUA DUQUE DE CAXIAS         RUA     SN
# freq                     36       19430   3240

# %% [markdown]
# ## Filtrar apenas escolas estaduais

# %%
data['nomedep'].unique()
# Out:
# array(['ESTADUAL - SE', 'MUNICIPAL', 'PRIVADA', 'ESTADUAL - OUTROS',
#        'FEDERAL'], dtype=object)

# %%
data = data[data['nomedep'].isin(['ESTADUAL - SE', 'ESTADUAL - OUTROS'])]

# %% [markdown]
# ## Juntar dados georrefenciados com desempenho das escolas (SARESP)

# %%
print('Quantidade de linhas', data.shape[0])
print('Valores unicos', data['CD_ESCOLA'].nunique())
# Out:
# Quantidade de linhas 6354
# Valores unicos 6074

# %%
data = data.drop_duplicates(subset=['CD_ESCOLA'])

# %%
data = pd.merge(data, df_escolas, left_on='CD_ESCOLA', right_on='CODESC', how='inner')

# %%
data = data.rename(columns={'DESEMPENHO_ESC': 'DESEMPENHO'})
data['DESEMPENHO'] = data['DESEMPENHO'].replace({0: 'RUIM', 1: 'BOM'})

# %% [markdown]
# ### Análise do desempenho por localização

# %%
df_desempenho_de = data.groupby('de')['DESEMPENHO'].value_counts(normalize=True).unstack()
df_desempenho_de = (df_desempenho_de.fillna(0) * 100).round(1)
df_desempenho_de
# Out:
# DESEMPENHO     BOM   RUIM
# de
# ADAMANTINA     3.1   96.9
# AMERICANA     26.6   73.4
# ANDRADINA      0.0  100.0
# APIAI          3.0   97.0
# ARACATUBA      0.0  100.0
# ...            ...    ...
# TAQUARITINGA  38.9   61.1
# TAUBATE        0.0  100.0
# TUPA          32.4   67.6
# VOTORANTIM     7.7   92.3
# VOTUPORANGA   14.3   85.7
#
# [91 rows x 2 columns]

# %%
df_desempenho_de.sort_values('BOM')['BOM'].plot(kind='barh',figsize=(20,20))

# %%
fig, ax = plt.subplots()
df_desempenho_de['BOM'].plot(kind='hist', bins=10, figsize=(14,10), ax=ax)

# %% [markdown]
# ## Juntar com base BRAZIL_CITIES

# %% [markdown]
# ### Limpar o nome dos municípios

# %%
df_cidades['CITY'] = df_cidades['CITY'].apply(lambda x: unidecode(x.upper().replace('-', ' ')))

# %%
df_cidades = df_cidades.drop_duplicates(subset=['STATE', 'CITY'])

# %%
data['mun'] = data['mun'].apply(lambda x: unidecode(x.upper().replace('-', ' ')))

# %%
'GDP', 'COMP_H', 'COMP_O', 'COMP_P', 'COMP_Q'
# Out:
# ('GDP', 'COMP_H', 'COMP_O', 'COMP_P', 'COMP_Q')

# %%
features_to_use = ['CITY', 'CAPITAL', 'AREA', 'ESTIMATED_POP', 'RURAL_URBAN', 'GVA_PUBLIC','GDP_CAPITA']

# %%
data = pd.merge(data, df_cidades[features_to_use], left_on='mun', right_on='CITY', how='left')

# %% [markdown]
# ## Análise Geoespacial

# %% [markdown]
# ### Leitura do shapefile de São Paulo
# Dados de: http://www.usp.br/nereus/?dados=unidades-federativas

# %%
# http://www.usp.br/nereus/?dados=unidades-federativas
gdf_sp = gpd.read_file('../data/external/SP-MUN')

# %% [markdown]
# ### Criação dos pontos georreferenciados

# %%
data['Points'] = data.apply(lambda x: Point(x['LONGITUDE'], x['LATITUDE']), axis=1)

# %%
gdf_points = gpd.GeoDataFrame(data, geometry='Points')

# %% [markdown]
# ## Visualização das escolas no mapa

# %%
ax = gdf_sp.plot(figsize=(14, 18))
gdf_points.plot(ax=ax, markersize=10, color='red', alpha=0.5)
plt.show()

# %% [markdown]
# ### Análise georreferenciada do desempenho escolar

# %%
ax = gdf_sp.plot(figsize=(14, 18))
gdf_points[gdf_points['DESEMPENHO'] == 'RUIM'].plot(ax=ax, markersize=10, color='red', alpha=0.3)
gdf_points[gdf_points['DESEMPENHO'] == 'BOM'].plot(ax=ax, markersize=10, color='yellow', alpha=0.3)
plt.show()

# %% [markdown]
# ## Exportar dados

# %%
data.drop([
    'nomedep', 'depadm', 'CD_DIRETORIA', 'CD_DIRETORIA_ESTADUAL', 'CD_DIRETORIA_SUPVS_PROPR', 'NM_COMPLETO_ESCOLA', 'CD_ORIGEM_UNIDADE', 'CD_ORIGEM_ESCOLA', 'CD_ORIGEM_ENDERECO', 'BOM', 'RUIM', 'DESEMPENHO', 'Points'
], axis=1, inplace=True)

# %%
data.head()
# Out:
#          mun  codmun       de  CD_ESCOLA  CD_UNIDADE           DS_ENDERECO  \
# 0  SAO PAULO     100  NORTE 1      36444       37806     DOMINGOS AREVALO
# 1  SAO PAULO     100  LESTE 5       1582       24902          21 DE ABRIL
# 2  SAO PAULO     100  LESTE 5       2173       24901              ITAPURA
# 3  SAO PAULO     100  LESTE 1       3086       24918  VIRGINIA DE MIRANDA
# 4  SAO PAULO     100  LESTE 1       2884       24923      RUA SAO BERTOLDO
#
#   COMPLEMENTO NUMERO   LATITUDE  LONGITUDE  CODESC       CITY  CAPITAL  \
# 0         RUA    862 -23.447000 -46.696700   36444  SAO PAULO        1
# 1         RUA    970 -23.542232 -46.605793    1582  SAO PAULO        1
# 2         RUA    976 -23.547300 -46.566000    2173  SAO PAULO        1
# 3         RUA    138 -23.526587 -46.452888    3086  SAO PAULO        1
# 4         RUA    449 -23.494297 -46.457064    2884  SAO PAULO        1
#
#       AREA  ESTIMATED_POP RURAL_URBAN   GVA_PUBLIC  GDP_CAPITA
# 0  1521.11     12176866.0      Urbano  41902892.72    57071.43
# 1  1521.11     12176866.0      Urbano  41902892.72    57071.43
# 2  1521.11     12176866.0      Urbano  41902892.72    57071.43
# 3  1521.11     12176866.0      Urbano  41902892.72    57071.43
# 4  1521.11     12176866.0      Urbano  41902892.72    57071.43

# %%
data.to_csv('../data/processed/localizacao.csv', index=False)
